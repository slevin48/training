# %% [markdown]
# # Immo 🏠
#
# Real estate prices in Paris

# %%
code = 75115
url = "https://26yrburrn0.execute-api.eu-west-3.amazonaws.com/dev/dvf?code_commune="+str(code)

# %%
import requests as rq
r = rq.get(url)
json = r.json()

# %%
json.keys()
# Out:
# dict_keys(['adresse_code_voie', 'adresse_nom_voie', 'adresse_numero', 'adresse_suffixe', 'ancien_code_commune', 'ancien_id_parcelle', 'ancien_nom_commune', 'code_commune', 'code_departement', 'code_nature_culture', 'code_nature_culture_speciale', 'code_postal', 'code_type_local', 'date_mutation', 'id_mutation', 'id_parcelle', 'latitude', 'longitude', 'lot1_numero', 'lot1_surface_carrez', 'lot2_numero', 'lot2_surface_carrez', 'lot3_numero', 'lot3_surface_carrez', 'lot4_numero', 'lot4_surface_carrez', 'lot5_numero', 'lot5_surface_carrez', 'nature_culture', 'nature_culture_speciale', 'nature_mutation', 'nom_commune', 'nombre_lots', 'nombre_pieces_principales', 'numero_disposition', 'numero_volume', 'surface_reelle_bati', 'surface_terrain', 'type_local', 'valeur_fonciere'])

# %%
json['valeur_fonciere']

# %%
dvf = pd.DataFrame(json)
dvf.head()
# Out:
#       adresse_code_voie    adresse_nom_voie  adresse_numero adresse_suffixe  \
# 10877              3705         RUE FONDARY            37.0             NaN
# 10878              6105       RUE MARMONTEL             8.0             NaN
# 10879              4147  RUE GEORGES PITARD            15.0             NaN
# 10880              5456        RUE LECOURBE           171.0             NaN
# 10881              5456        RUE LECOURBE            18.0             NaN
#
#        ancien_code_commune  ancien_id_parcelle  ancien_nom_commune  \
# 10877                  NaN                 NaN                 NaN
# 10878                  NaN                 NaN                 NaN
# 10879                  NaN                 NaN                 NaN
# 10880                  NaN                 NaN                 NaN
# 10881                  NaN                 NaN                 NaN
#
#        code_commune  code_departement code_nature_culture  ...  \
# 10877         75115                75                 NaN  ...
# 10878         75115                75                 NaN  ...
# 10879         75115                75                 NaN  ...
# 10880         75115                75                 NaN  ...
# 10881         75115                75                 NaN  ...
#
#        nature_mutation               nom_commune  nombre_lots  \
# 10877            Vente  Paris 15e Arrondissement            2
# 10878            Vente  Paris 15e Arrondissement            2
# 10879            Vente  Paris 15e Arrondissement            1
# 10880            Vente  Paris 15e Arrondissement            1
# 10881            Vente  Paris 15e Arrondissement            1
#
#       nombre_pieces_principales numero_disposition numero_volume  \
# 10877                       3.0                  1           NaN
# 10878                       2.0                  1           NaN
# 10879                       0.0                  1           NaN
# 10880                       0.0                  1           NaN
# 10881                       0.0                  1           NaN
#
#        surface_reelle_bati  surface_terrain  \
# 10877                 62.0              NaN
# 10878                 37.0              NaN
# 10879                 50.0              NaN
# 10880                  NaN              NaN
# 10881                  NaN              NaN
#
#                                      type_local  valeur_fonciere
# 10877                               Appartement         607500.0
# 10878                               Appartement         573721.0
# 10879  Local industriel. commercial ou assimilé         233000.0
# 10880                                Dépendance          30000.0
# 10881                                Dépendance         690000.0
#
# [5 rows x 40 columns]
